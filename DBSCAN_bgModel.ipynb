# %% [markdown]
# <a href="https://colab.research.google.com/github/mbibrahe/BA_Project/blob/main/DBSCAN_bgSub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import tensorflow as tf
#tf.compat.v1.enable_eager_execution()

# %%
#!ls */train/*

# %%
from __future__ import print_function
import glob, os, numpy as np
from keras.preprocessing import image as kImage
from __future__ import print_function
import numpy as np
import random as rn
import os
from tensorflow.compat.v1.keras import backend as K

# %%
''
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id': '12Kps2O0x-kxQyqBKJFs-xeSenpggMAEe'})
download.GetContentFile("16_samples.zip")


! unzip 16_samples.zip

from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 16_samples/train/z/2/bg2 - Copy (675) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (676) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (677) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (678) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (679) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (68) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (68) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (680) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (681) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (682) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (683) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (684) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (685) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (686) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (687) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (688) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (689) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (69) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (69) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (690) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (691) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (692) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (693) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (694) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (695) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (696) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (697) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (698) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (699) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (7) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (7) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (7) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (7).jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (70) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (70) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (700) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (701) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (702) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (703) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (704) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (705) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (706) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (707) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (708) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (709) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (71) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (71) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (710) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (711) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (712) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (713) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (714) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (715) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (716) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (717) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (718) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (719) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (72) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (72) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (720) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (721) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (722) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (723) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (724) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (725) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (726) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (727) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (728) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (729) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (73) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (73) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (730) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (731) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (732) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (733) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (734) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (735) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (736) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (737) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (738) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (739) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (74) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (74) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (740) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (741) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (742) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (743) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (744) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (745) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (746) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (747) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (748) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (749) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (75) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (75) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (750) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (751) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (752) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (753) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (754) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (755) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (756) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (757) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (758) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (759) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (76) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (76) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (760) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (761) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (762) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (763) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (764) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (765) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (766) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (767) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (768) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (769) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (77) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (77) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (770) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (771) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (772) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (773) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (774) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (775) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (776) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (777) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (778) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (779) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (78) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (78) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (780) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (781) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (782) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (783) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (784) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (785) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (786) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (787) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (788) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (789) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (79) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (79) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (790) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (791) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (792) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (793) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (794) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (795) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (796) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (797) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (798) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (799) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (8) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (8) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (8) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (8).jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (80) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (80) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (800) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (801) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (802) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (803) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (804) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (805) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (806) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (807) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (808) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (809) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (81) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (81) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (810) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (811) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (812) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (813) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (814) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (815) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (816) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (817) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (818) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (819) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (82) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (82) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (820) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (821) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (822) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (823) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (824) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (825) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (826) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (827) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (828) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (829) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (83) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (83) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (830) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (831) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (832) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (833) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (834) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (835) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (836) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (837) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (838) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (839) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (84) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (84) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (840) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (841) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (842) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (843) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (844) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (845) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (846) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (847) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (848) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (849) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (85) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (85) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (850) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (851) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (852) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (853) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (854) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (855) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (856) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (857) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (858) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (859) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (86) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (86) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (860) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (861) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (862) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (863) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (864) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (865) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (866) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (867) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (868) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (869) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (87) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (87) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (870) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (871) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (872) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (873) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (874) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (875) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (876) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (877) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (878) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (879) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (88) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (88) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (880) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (881) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (882) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (883) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (884) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (885) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (886) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (887) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (888) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (889) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (89) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (89) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (890) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (891) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (892) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (893) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (894) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (895) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (896) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (897) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (898) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (899) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (9) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (9) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (9) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (9).jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (90) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (90) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (900) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (901) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (902) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (903) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (904) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (905) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (906) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (907) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (908) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (909) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (91) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (91) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (910) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (911) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (912) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (913) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (914) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (915) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (916) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (917) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (918) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (919) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (92) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (92) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (920) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (921) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (922) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (923) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (924) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (925) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (926) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (927) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (928) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (929) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (93) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (93) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (930) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (931) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (932) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (933) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (934) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (935) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (936) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (937) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (938) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (939) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (94) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (94) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (940) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (941) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (942) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (943) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (944) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (945) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (946) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (947) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (948) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (949) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (95) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (95) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (950) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (951) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (952) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (953) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (954) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (955) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (956) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (957) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (958) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (959) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (96) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (96) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (960) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (961) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (962) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (963) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (964) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (965) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (966) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (967) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (968) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (969) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (97) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (97) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (970) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (971) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (972) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (973) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (974) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (975) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (976) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (977) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (978) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (979) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (98) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (98) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (980) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (981) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (982) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (983) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (984) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (985) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (986) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (99) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy (99) - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2 - Copy.jpg
#   inflating: 16_samples/train/z/2/bg2.jpg
#    creating: 16_samples/train/z/20/
#   inflating: 16_samples/train/z/20/bg20 - Copy (172) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (172) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (173) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (173) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (173) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (174) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (174) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (174) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (175) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (175) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (175) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (176) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (176) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (176) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (177) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (177) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (177) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (178) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (178) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (178) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (179) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (179) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (179) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (180) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (180) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (180) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (181) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (181) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (181) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (182) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (182) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (182) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (183) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (183) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (183) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (184) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (184) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (184) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (185) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (185) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (185) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (186) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (186) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (186) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (187) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (187) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (187) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (188) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (188) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (188) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (189) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (189) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (189) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (190) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (190) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (190) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (191) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (191) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (191) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (192) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (192) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (192) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (193) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (193) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (193) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (194) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (194) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (194) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (195) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (195) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (195) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (196) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (196) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (196) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (197) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (197) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (197) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (198) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (198) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (198) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (199) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (199) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (199) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (200) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (200) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (200) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (201) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (201) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (201) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (202) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (202) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (202) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (203) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (203) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (203) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (204) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (204) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (204) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (205) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (205) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (205) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (206) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (206) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (206) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (207) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (207) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (207) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (208) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (208) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (208) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (209) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (209) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (209) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (210) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (210) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (210) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (211) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (211) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (211) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (212) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (212) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (212) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (213) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (213) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (213) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (214) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (214) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (214) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (215) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (215) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (215) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (216) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (216) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (216) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (217) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (217) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (217) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (218) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (218) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (218) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (219) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (219) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (219) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (220) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (220) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (220) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (221) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (221) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (221) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (222) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (222) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (222) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (223) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (223) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (223) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (224) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (224) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (224) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (225) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (225) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (225) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (226) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (226) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (226) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (227) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (227) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (227) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (228) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (228) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (228) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (229) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (229) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (229) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (230) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (230) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (230) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (231) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (231) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (231) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (232) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (232) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (232) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (233) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (233) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (233) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (234) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (234) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (234) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (235) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (235) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (235) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (236) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (236) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (236) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (237) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (237) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (237) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (238) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (238) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (238) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (239) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (239) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (239) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (240) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (240) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (240) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (241) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (241) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (241) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (242) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (242) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (242) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (243) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (243) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (243) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (244) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (244) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (244) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (245) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (245) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (245) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (246) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (246) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (246) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (247) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (247) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (247) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (248) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (248) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (248) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (249) - Copy - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (249) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (249) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (249) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (250) - Copy - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (250) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (250) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (250) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (251) - Copy - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (251) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (251) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (251) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (252) - Copy - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (252) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (252) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (252) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (253) - Copy - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (253) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (253) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (253) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (254) - Copy - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (254) - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (254) - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (254) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (255) - Copy - Copy - Copy - Copy - Copy.jpg
#   inflating: 16_samples/train/z/20/bg20 - Copy (255) - Copy - Copy - Copy - Copy.jpg
# ...
#   inflating: 16_samples/train/z/4/bg4 - Copy (77) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (78) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (78) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (79) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (79) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (8) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (8) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (8).jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (80) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (80) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (81) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (81) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (82) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (82) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (83) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (83) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (84) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (84) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (85) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (85) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (86) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (86) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (87) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (87) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (88) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (88) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (89) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (89) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (9) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (9) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (9).jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (90) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (90) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (91) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (91) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (92) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (92) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (93) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (93) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (94) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (94) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (95) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (95) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (96) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (96) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (97) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (97) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (98) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (98) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (99) - Copy - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy (99) - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4 - Copy.jpg
#   inflating: 16_samples/train/z/4/bg4.jpg
#    creating: 16_samples/train/z/8/
#   inflating: 16_samples/train/z/8/bg8 - Copy - Copy (2).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy - Copy (3).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy - Copy (4).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy - Copy (5).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy - Copy (6).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy - Copy (7).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy - Copy (8).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy - Copy (9).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (10) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (10).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (100) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (101) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (102) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (103) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (104) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (105) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (106) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (107) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (108) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (109) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (11) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (11).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (110) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (111) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (112) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (113) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (114) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (115) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (116) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (117) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (118) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (119) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (12) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (12).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (120) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (121) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (122) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (123) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (124) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (125) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (126) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (127) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (128) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (129) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (13) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (13).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (130) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (131) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (132) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (133) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (134) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (135) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (136) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (137) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (138) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (139) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (14) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (14).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (140) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (141) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (142) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (143) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (144) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (145) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (146) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (147) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (148) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (149) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (15) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (15).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (150) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (151) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (152) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (153) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (154) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (155) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (156) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (157) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (158) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (159) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (16) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (16).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (160) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (161) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (162) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (163) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (17) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (17).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (18) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (18).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (19) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (19).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (2) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (2).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (20) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (20).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (21) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (21).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (22) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (22).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (23) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (23).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (24) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (24).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (25) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (25).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (26) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (26).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (27) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (27).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (28) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (28).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (29) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (3) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (3).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (30) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (31) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (32) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (33) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (34) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (35) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (36) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (37) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (38) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (39) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (4) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (4).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (40) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (41) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (42) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (43) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (44) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (45) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (46) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (47) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (48) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (49) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (5) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (5).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (50) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (51) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (52) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (53) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (54) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (55) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (56) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (57) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (58) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (59) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (6) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (6).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (60) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (61) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (62) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (63) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (64) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (65) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (66) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (67) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (68) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (69) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (7) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (7).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (70) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (71) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (72) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (73) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (74) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (75) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (76) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (77) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (78) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (79) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (8) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (8).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (80) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (81) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (82) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (83) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (84) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (85) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (86) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (87) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (88) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (89) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (9) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (9).jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (90) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (91) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (92) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (93) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (94) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (95) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (96) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (97) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (98) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy (99) - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8 - Copy.jpg
#   inflating: 16_samples/train/z/8/bg8.jpg
# Mounted at /content/drive

# %%
import numpy as np

import keras
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D, AveragePooling2D, GlobalAveragePooling3D
from keras.models import Sequential
from keras.layers.convolutional import Deconv2D, Conv2DTranspose
from keras.layers import Activation, Input, Dropout, BatchNormalization, SpatialDropout2D, LayerNormalization
from keras.layers.merge import concatenate
import keras.backend as K
import tensorflow as tf
from keras import regularizers
from PIL import Image as PILimage
import matplotlib.pyplot as plt
from matplotlib import image as imageMat
from keras import backend as K
from sklearn.datasets import load_sample_image
from sklearn.feature_extraction import image as Image
from sklearn.datasets import load_sample_image
from sklearn.mixture import GaussianMixture
from sklearn.neighbors import NearestNeighbors
import cv2 as cv
from numba import vectorize, jit, cuda 


import sys, time

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS

# Load images into array as graycale 320*240
dataset_path = os.path.join('16_samples')
def getData(dataset_dir):
    X_list11= sorted(glob.glob(os.path.join(dataset_dir, 'train', 'x','4','*.jpg')))
    


    X_gray= []
    X= []



    #Run for less frames
    for i in range(0, len(X_list11)):
        # Load input image
        
        x_gray = cv.imread(X_list11[i], 0)
        x_gray = cv.normalize(x_gray, None, alpha=0, beta=1, norm_type=cv.NORM_MINMAX, dtype=cv.CV_32F)
        X_gray.append(x_gray)



        x = cv.imread(X_list11[i])
        X.append(x)

    X_gray = np.asarray(X_gray)
    X = np.asarray(X)

    return X_gray, X

X_gray, X = getData(dataset_path)

print(X_gray[0].shape)

"""for i in range(0,10):
  plt.imshow(X[i])
  plt.show()"""
# Out:
# (576, 720)
# 'for i in range(0,10):\n  plt.imshow(X[i])\n  plt.show()'

# %%
import heapq
import statistics
from collections import Counter
#@jit(target ="cpu")
"""def nn_epsilon(frames):

  #We find the optimal value for epsilon, using k-nearest neighbor.
  #Reshaping (flattening) the grayscale 3d array, into a 2d array
  #nsamples, nx, ny = frames.shape
  #d2_X = frames.reshape((nsamples,nx*ny))
  #print(d2_X.shape)
  temp_ = []

  #We find the nearest 2 neighbors for each pixel in the same frame.
  #Returns the 2 indices of the nearest 2 neighbors, aswell as the euclidean distance (in a straight line) to those neighbors.
  #We run for n frames, appending the max euclidean distances to the 2nd neighbor (the neighbor which is not itself)




  shape = (len(frames), len(frames[0]), len(frames[0][0]))
    

   
  #iterate through rows
  for r in range(0, shape[1]):
      row = []
      #iterate through cols
      for c in range(0, shape[2]):

          #Create temp array of current r, c pixel for EVERY frame in the original video.
          #This means, we create an array of length 200, where each element is the rgb values, 
          #for pixel at location 1,1, then at location 1,2 and so on.
          pixels = np.array([frame[r][c] for frame in frames])
          #print(pixels)
            
          # Compute the means
          #pixels = pixels.reshape(-1, 1)
          nbrs = NearestNeighbors(n_neighbors=2).fit(pixels)
          distances, indices = nbrs.kneighbors(pixels)
          distances = distances[:,1]
          #top_distances = heapq.nlargest(round(len(distances)/8), distances)
          #temp_.append(sum(top_distances)/len(top_distances))
          temp_.append(sum(distances)/len(distances))
  
  temp_arr = np.array(temp_)
  #We sort the average euclidean distances in ascending order 
  temp_arr = np.sort(temp_arr, axis=0)
  #print(temp_arr)
  plt.plot(temp_arr)
  plt.show()

  #We approach the point of maximum curvature (elbow)
  ####### IS THIS NECESSARY ########## 
  dif_ = [j-i for i, j in zip(temp_arr[:-1], temp_arr[1:])]

  #Zip original distances with dif_, and find the distance with largest dif_
  avg_dif = sum(dif_)/len(dif_)
  n_zip = zip(temp_arr, dif_)
  tip_ = []
  for x, y in n_zip:
    if (y > avg_dif):
      tip_.append(x)
  #print(len(tip_))
  list_of_max = heapq.nsmallest(round(len(tip_)/2), tip_)
  avg_max_dif = sum(list_of_max)/len(list_of_max)
  
  
  #plt.plot(temp_arr)
  #plt.show()
  return avg_max_dif"""
#nn_epsilon(X_gray)

#Code for fix_photo:
#https://github.com/vimlord/Clustering-Background-Subtraction


#Epsilon is the maximum distance between to samples, for them to be clustered in the same neighborhood
#Min_points is the minimum number of samples in a neighborhood for a data point to qualify as a core point 
#Frames = out dataset, eps = the optimal calculated epsilon, minPts = dataset dim*2

def fix_photo(frames, grey_frames, eps=0.00, minPts = 6):
    #eps_ = nn_epsilon(grey_frames)
    
    shape = (len(frames), len(frames[0]), len(frames[0][0]))
    
    image = []

    bar_width = 40
    bar_prog = 0
    start = time.time()
    
    sys.stdout.write("Running DBSCAN...\nProgress: 0/" + str(shape[1]) + " [" + (bar_width * " ") + "] ETA: N/A")
    sys.stdout.flush()
    #iterate through rows
    for r in range(0, shape[1]):
        row = []
        #iterate through cols
        for c in range(0, shape[2]):

            #Create temp array of current r, c pixel for EVERY frame in the original video.
            #This means, we create an array of length 200, where each element is the rgb values, 
            #for pixel at location 1,1, then at location 1,2 and so on.
            pixels = np.array([frame[r][c] for frame in frames])
            pixels_grey = np.array([frame[r][c] for frame in grey_frames])

            nbrs = NearestNeighbors(n_neighbors=2).fit(pixels_grey)
            distances, indices = nbrs.kneighbors(pixels_grey)
            distances = distances[:,1]
            #top_distances = heapq.nlargest(round(len(distances)/8), distances)
            #temp_.append(sum(top_distances)/len(top_distances))
            temp_eps = sum(distances)/len(distances)
            
            #https://github.com/facebookresearch/faiss/issues/297
            #If any distances values are negativ because of a roundoff error
            #Or if any distances are zero
            epsilon = abs(temp_eps) + 0.00001
            
            
            
            # Compute the means
            
            db = DBSCAN(eps=epsilon, min_samples=minPts).fit(pixels)

            
            
            # Grab label information.
            labels = db.labels_
            
            label_set = set(labels)
            label_count = {l : 0 for l in label_set}
            
            # Compute label frequency
            for l in labels:
                label_count[l] += 1
            
            # Choose a cluster.
            choice = None
            for l in label_set:
                if choice is None and l > -1:
                    choice = l
            
            # Apply the pixel if it exists.
            if choice is None:
                row.append(np.mean(pixels, axis=0))
            else:
                row.append(np.mean(np.array([pixels[i] for i in range(len(labels)) if labels[i] == choice]), axis=0))
                   
        # Provide the image
        image.append(row)
        
        # Bar progress
        bar_prog = int((bar_width * (r+1.)) / shape[1])
        
        # Time remaining
        t = time.time() - start
        t = (shape[1] * t / (r+1.0)) - t

        sys.stdout.write("\rProgress: " + str(r+1) + "/" + str(shape[1]) + " [" + ("#" * bar_prog) + (" " * (bar_width - bar_prog)) + "] ETA: ")
        sys.stdout.write(time.strftime("%H hr %M min", time.gmtime(t)))
        sys.stdout.flush()

    sys.stdout.write("\rProgress: " + str(shape[1]) + "/" + str(shape[1]) + " [" + ("#" * bar_prog) + (" " * (bar_width - bar_prog)) + "] Done! ")

    print(time.strftime("(Time: %H hr %M min)", time.gmtime(time.time() - start)))

    return image



res = np.array(fix_photo(X, X)).astype(np.uint8)
# Out:
# Running DBSCAN...
# Progress: 576/576 [########################################] Done! (Time: 00 hr 57 min)

# %%
plt.imshow(res)
plt.show()

# %%
cv.imwrite ('/content/drive/My Drive/full_bgtest1.jpg', res)
# Out:
# True
